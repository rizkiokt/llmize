# %%
import numpy as np
import os
import subprocess
import time
import re

from llmize import OPRO, HLMEA, HLMSA
import llmize

# %%
KEYS = ["FUE1_enr", "FUE2_enr", "FUE3_enr", "FUE4_enr", "FUE5_enr", "FUE6_enr", "FUE7_enr",
                    "FUE8_enr", "FUE8_gads", "FUE9_enr", "FUE9_gads", "FUE10_enr", "FUE10_gads", "FUE11_enr", "FUE11_gads"]
TEMPLATE_FILE = "GE14.DOM.BOC.inp"

# %%
with open(TEMPLATE_FILE, 'r') as file:
    template_content = file.readlines()

# %%
def read_cas5_out(c5_out_filepath):
    output_dict = {}
    
    with open(c5_out_filepath, 'r') as file:
        lines = file.readlines()
    
    # Locate the summary section
    summary_index = None
    for i, line in enumerate(lines):
        if "** C A S M O 5  Summary **" in line:
            summary_index = i
            break
    
    if summary_index is None:
        print("Warning: CASMO5 summary section not found in file.")
        return None
    
    # Find the column names starting with "No"
    column_names = []
    data_start_index = None
    for i in range(summary_index, len(lines)):
        if lines[i].strip().startswith("No"):
            column_names = re.split(r'\s+', lines[i].strip())
            column_names = [col for col in column_names if "Pu" not in col]  # Remove columns containing "Pu"
            data_start_index = i + 1
            break
    
    i = 0
    for col in column_names:
        if col == 'Pin':
            column_names[i] = 'Pin Peak'
        if col == 'Fiss' or col == 'Tot':
            column_names[i] = col + ' Pu'
        i = i + 1
    
    if not column_names or data_start_index is None:
        print("Warning: Column header line not found after CASMO5 summary section.")
        return None
    
    # Process the data
    last_values = {}
    first_entry_found = False
    index = 0
    for i in range(data_start_index, len(lines)):
        line = lines[i].strip()
        if not line:
            continue
        
        parts = re.split(r'\s+', line)
        
        # First entry should be an integer (record index number)
        prev_index = index
        try:
            index = int(parts[0])
            if index<prev_index:
                break

        except ValueError:
            continue
        
        full_data = {}
        
        # First occurrence of No=1 contains all values
        if index == 1 and not first_entry_found:
            for j, col in enumerate(column_names):
                full_data[col] = parts[j] if j < len(parts) else ''
                last_values[col] = full_data[col]  # Store as last valid values
            first_entry_found = True
        else:
            # Fill missing values with previous ones
            for j, col in enumerate(column_names):
                if j < len(parts) and parts[j]:
                    full_data[col] = parts[j]
                    last_values[col] = parts[j]  # Store last valid value
                else:
                    full_data[col] = last_values.get(col, '')  # Use last recorded value if missing
        
        output_dict[index] = full_data
    
    return output_dict

# %%
def parse_lattice_data(solution_list):

    lattice_data = {}
    i = 0
    for data in solution_list:
        key = KEYS[i]
        lattice_data[key] = float(data)
        i += 1

    return lattice_data


def gen_lattice_inp(template_content, folder_name, lattice_name, lattice_data):
    """
    Function to generate a perturbed lattice input file based on pre-generated lattice data.

    Parameters:
        template_content (list): List of strings representing template file lines.
        folder_name (str): Directory where the new lattice file will be saved.
        lattice_name (str): Name of the lattice.
        lattice_data (dict): Dictionary containing pre-generated perturbation data.

    Returns:
        str: Path to the generated lattice input file.
    """
    # Create the output file path
    output_file = os.path.join(folder_name, f"{lattice_name}.BOC.inp")

    # Apply perturbations based on the provided lattice data
    perturbed_content = []
    for line in template_content:
        if line.startswith("FUE"):
            parts = line.split()
            fue_num = int(parts[1])

            # Apply enrichment perturbation if available
            if f"FUE{fue_num}_enr" in lattice_data:
                parts[4] = f"{lattice_data[f'FUE{fue_num}_enr']:.1f}"

            # Apply gads perturbation if available
            if f"FUE{fue_num}_gads" in lattice_data:
                parts[-1] = f"64016={lattice_data[f'FUE{fue_num}_gads']:.1f}"
            
            line = " ".join(parts) + "\n"

        elif line.startswith("IDE"):
            line = f"IDE='{lattice_name}'\n"

        elif line.startswith("SIM"):
            line = f"SIM '{lattice_name}'\n"

        perturbed_content.append(line)
        
    # Write the perturbed content to the new file
    with open(output_file, 'w') as file:
        file.writelines(perturbed_content)
    #print(f"Written perturbed input file: {output_file}")

    return output_file
    

def eval_cas5_boc(file_path):

    folder_name, file_name = os.path.split(file_path)
    log_file = file_name[:-3] + 'log'

    if os.path.exists(folder_name) and os.path.exists(os.path.join(folder_name, file_name)):
        #print(f"Running simulation for {file_path} in background...")
        #print("current directory", os.getcwd())
        os.chdir(folder_name)

        with open(log_file, "w") as log:
            process = subprocess.Popen(["cas5", file_name], stdin=subprocess.PIPE, stdout=log, stderr=log)
            process.stdin.write(b"y\n")
            process.stdin.close()

        time.sleep(5)
        # Wait until no files starting with "tmp" exist
        while any(f.startswith('tmp.'+file_name[:-3]) for f in os.listdir('.')):
            #print(f"Waiting for temporary files to be cleared for {file_path}...")
            time.sleep(1)

        os.chdir("..")
    else:
        print(f"Directory or file {os.path.join(folder_name, file_name)} does not exist.")
    
    outfile_name = file_name[:-3] + 'out'
    c5_out_filepath = os.path.join(folder_name, outfile_name)
    output_dict = read_cas5_out(c5_out_filepath)

    kinf = float(output_dict[1]['K-inf'])
    ppf = float(output_dict[1]['Pin Peak'])

    return kinf, ppf

def calc_score(kinf, ppf, target_kinf=1.05, target_ppf=1.33, kinf_tol=0.001, ppf_tol=0.00):

    kinf_penalty = 0
    ppf_penalty = 0
    if kinf < (target_kinf - kinf_tol):
        kinf_penalty = 200*(target_kinf-kinf)
    if kinf > (target_kinf + kinf_tol):
        kinf_penalty = 200*(kinf-target_kinf)
    if ppf > (target_ppf + ppf_tol):
        ppf_penalty = 100*(ppf-target_ppf)

    score = 100-kinf_penalty-ppf_penalty
    score = round(score, 2)
    return score


def objective_function(solution_list, template_content):
    lattice_data = parse_lattice_data(solution_list)
    file_path = gen_lattice_inp(template_content, "cas5_runs", lattice_name="GE14", lattice_data=lattice_data)
    kinf, ppf = eval_cas5_boc(file_path)
    score = calc_score(kinf, ppf)

    return score

# %%
# Generate initial solution by random perturbation of this:
# ["FUE1_enr", "FUE2_enr", "FUE3_enr", "FUE4_enr", "FUE5_enr", "FUE6_enr", "FUE7_enr",
# "FUE8_enr", "FUE8_gads", "FUE9_enr", "FUE9_gads", "FUE10_enr", "FUE10_gads", "FUE11_enr", "FUE11_gads"]

# enrichments are between 1 to 5% with 0.1% step
# gadolinia has maximum 10% with increment of 1% step

# set seed for reproducibility
np.random.seed(42)

def generate_initial_solutions(n_solutions=10):
    solutions = []
    for _ in range(n_solutions):
        # Generate random enrichments between 1-5% with 0.1% steps
        enrichments = np.round(np.random.choice(np.arange(3.6, 5.1, 0.1), size=11), decimals=1)
        enrichments[0] = np.round(np.random.choice(np.arange(1.5, 2.1, 0.1), size=1), decimals=1)
        enrichments[1] = np.round(np.random.choice(np.arange(2.0, 3.1, 0.1), size=1), decimals=1)
        enrichments[2] = np.round(np.random.choice(np.arange(2.0, 3.1, 0.1), size=1), decimals=1)

        # Generate random gadolinia content between 0-10% with 1% steps
        gads = np.round(np.random.choice(np.arange(4.0, 10.0, 1.0), size=4), decimals=1)
        # Combine into solution array
        solution = []
        for i in range(7):  # FUE1-7 enrichments only
            solution.append(enrichments[i])
        
        # Add FUE8-11 enrichments and gadolinia
        solution.extend([enrichments[7], gads[0]])  # FUE8
        solution.extend([enrichments[8], gads[1]])  # FUE9  
        solution.extend([enrichments[9], gads[2]])  # FUE10
        solution.extend([enrichments[10], gads[3]]) # FUE11
        
        solutions.append(solution)
        
    return solutions

batch_size = 16

solutions = generate_initial_solutions(n_solutions=batch_size)
for solution in solutions:
    print(solution)
# Out:
# [np.float64(4.8), np.float64(3.8), np.float64(2.4), np.float64(1.7), np.float64(3.0), np.float64(4.8), np.float64(2.8), np.float64(3.2), np.float64(8.0), np.float64(2.0), np.float64(7.0), np.float64(2.0), np.float64(6.0), np.float64(3.3), np.float64(9.0)]
# [np.float64(1.1), np.float64(3.3), np.float64(3.9), np.float64(4.7), np.float64(1.1), np.float64(3.0), np.float64(4.2), np.float64(2.1), np.float64(6.0), np.float64(3.1), np.float64(5.0), np.float64(3.4), np.float64(7.0), np.float64(3.6), np.float64(7.0)]
# [np.float64(2.5), np.float64(2.4), np.float64(1.2), np.float64(4.6), np.float64(1.6), np.float64(3.0), np.float64(1.8), np.float64(4.8), np.float64(7.0), np.float64(2.7), np.float64(9.0), np.float64(1.3), np.float64(5.0), np.float64(3.4), np.float64(5.0)]
# [np.float64(1.8), np.float64(3.5), np.float64(1.1), np.float64(2.9), np.float64(3.7), np.float64(1.6), np.float64(1.7), np.float64(4.4), np.float64(5.0), np.float64(2.3), np.float64(7.0), np.float64(2.6), np.float64(5.0), np.float64(4.5), np.float64(9.0)]
# [np.float64(1.5), np.float64(1.3), np.float64(3.8), np.float64(2.7), np.float64(3.5), np.float64(4.3), np.float64(1.9), np.float64(4.5), np.float64(9.0), np.float64(2.3), np.float64(7.0), np.float64(4.0), np.float64(4.0), np.float64(2.4), np.float64(9.0)]
# [np.float64(4.9), np.float64(3.0), np.float64(2.5), np.float64(2.7), np.float64(3.3), np.float64(3.5), np.float64(3.4), np.float64(5.0), np.float64(4.0), np.float64(3.8), np.float64(4.0), np.float64(2.4), np.float64(4.0), np.float64(1.0), np.float64(7.0)]
# [np.float64(1.7), np.float64(3.3), np.float64(2.0), np.float64(2.6), np.float64(1.7), np.float64(4.4), np.float64(4.4), np.float64(4.2), np.float64(7.0), np.float64(1.4), np.float64(4.0), np.float64(4.8), np.float64(7.0), np.float64(5.0), np.float64(5.0)]
# [np.float64(4.2), np.float64(3.2), np.float64(3.3), np.float64(4.6), np.float64(4.4), np.float64(4.9), np.float64(3.1), np.float64(3.6), np.float64(8.0), np.float64(4.4), np.float64(9.0), np.float64(1.0), np.float64(6.0), np.float64(4.4), np.float64(4.0)]
# [np.float64(1.4), np.float64(3.5), np.float64(2.3), np.float64(4.8), np.float64(3.6), np.float64(1.8), np.float64(2.4), np.float64(2.4), np.float64(4.0), np.float64(3.5), np.float64(7.0), np.float64(2.2), np.float64(8.0), np.float64(4.1), np.float64(7.0)]
# [np.float64(3.9), np.float64(4.6), np.float64(3.2), np.float64(4.8), np.float64(2.4), np.float64(3.8), np.float64(4.5), np.float64(2.2), np.float64(7.0), np.float64(4.1), np.float64(5.0), np.float64(1.6), np.float64(5.0), np.float64(3.1), np.float64(8.0)]
# [np.float64(1.5), np.float64(3.7), np.float64(3.7), np.float64(2.9), np.float64(3.9), np.float64(2.0), np.float64(3.7), np.float64(3.4), np.float64(4.0), np.float64(4.8), np.float64(6.0), np.float64(4.2), np.float64(9.0), np.float64(1.0), np.float64(4.0)]
# [np.float64(2.2), np.float64(5.0), np.float64(1.2), np.float64(4.8), np.float64(1.5), np.float64(1.7), np.float64(3.6), np.float64(1.8), np.float64(6.0), np.float64(4.6), np.float64(9.0), np.float64(4.2), np.float64(4.0), np.float64(3.3), np.float64(7.0)]
# [np.float64(2.1), np.float64(4.8), np.float64(1.1), np.float64(1.2), np.float64(4.6), np.float64(2.6), np.float64(1.1), np.float64(1.1), np.float64(4.0), np.float64(3.7), np.float64(4.0), np.float64(3.2), np.float64(6.0), np.float64(4.6), np.float64(9.0)]
# [np.float64(1.1), np.float64(3.5), np.float64(4.1), np.float64(1.5), np.float64(4.1), np.float64(1.3), np.float64(2.0), np.float64(2.6), np.float64(7.0), np.float64(4.7), np.float64(5.0), np.float64(3.3), np.float64(9.0), np.float64(1.4), np.float64(9.0)]
# [np.float64(2.0), np.float64(2.5), np.float64(4.2), np.float64(1.8), np.float64(1.5), np.float64(2.5), np.float64(3.8), np.float64(1.2), np.float64(5.0), np.float64(2.9), np.float64(6.0), np.float64(4.5), np.float64(6.0), np.float64(2.8), np.float64(7.0)]
# [np.float64(4.1), np.float64(1.6), np.float64(5.0), np.float64(4.2), np.float64(4.9), np.float64(4.8), np.float64(2.7), np.float64(4.9), np.float64(4.0), np.float64(1.0), np.float64(4.0), np.float64(2.0), np.float64(5.0), np.float64(3.7), np.float64(9.0)]

# %%
scores = []
for solution in solutions:
    score = objective_function(solution_list=solution, template_content=template_content)
    scores.append(score)
    print(score)

print(scores)
# Out:
# -34.29
# 0.63
# -15.01
# -25.88
# 23.88
# -33.06
# 17.8
# 29.72
# 4.85
# 4.94
# 21.99
# -94.05
# -60.96
# -13.29
# -33.88
# 25.67
# [-34.29, 0.63, -15.01, -25.88, 23.88, -33.06, 17.8, 29.72, 4.85, 4.94, 21.99, -94.05, -60.96, -13.29, -33.88, 25.67]

# %%
with open("bwr_ge14.txt", "r") as f:
    problem_text = f.read()

obj_func = lambda x: objective_function(x, template_content)


# Initialize the OPRO optimizer
opro = OPRO(problem_text=problem_text, obj_func=obj_func,
            llm_model="gemini-2.0-flash-thinking-exp", api_key=os.getenv("GEMINI_API_KEY"))

prompt = opro.get_sample_prompt(init_samples=solutions, init_scores=scores, optimization_type="maximize")
response = opro.get_sample_response(prompt)

llmize.utils.pretty_print(prompt=prompt, response=response)
# Out:
# ======================================================================================================================================================
# Prompt:
# You are an optimization agent and an expert in nuclear reactor design. Your task is to generate a 10×10 GE-14 fuel lattice design that satisfies the
# following conditions:
#
# - Fuel Enrichment (FUE#_enr): Maximum 5.0% with increments of 0.1%.
# - Gadolinia Content (FUE#_gads): Maximum 10.0% with increments of 1.0%.
#
# Lattice Configuration:
# Here is the half-lattice map (symmetric arrangement assumed):
# 1
# 2  7
# 3  8  5
# 7  4  9  6
# 4 10  5 11  5
# 4  5 11  0  0  5
# 7  5  6  0  0  5 10
# 7  5  5  5  5  5  5  5
# 3  6 10  5  5  5  5  5 10
# 2  7  6  6  6  6  6  6  4  7
#
# Objective:
# Your goal is to generate new solutions that achieve:
# - Lattice criticality: k_inf = 1.05
# - Pin Peaking Factor (PPF): <1.30
# - Higher score than any of the given solutions.
#
# The objective function (score) is determined based on these parameters, but you are not to guess k_inf, PPF, or score—they will be calculated
# externally using Casmo-5 simulations and a processing code.
# Maximum score is 100.0, which is achieved when all the constraints are satisfied.
#
# Solution Format:
# Each solution must include values for the following parameters:
# FUE1_enr, FUE2_enr, FUE3_enr, FUE4_enr, FUE5_enr, FUE6_enr, FUE7_enr, FUE8_enr, FUE8_gads, FUE9_enr, FUE9_gads, FUE10_enr, FUE10_gads, FUE11_enr,
# FUE11_gads
#
# Below are some examples of solutions and their scores:
#
# <sol> 4.8,3.8,2.4,1.7,3.0,4.8,2.8,3.2,8.0,2.0,7.0,2.0,6.0,3.3,9.0 <\sol>
# score: -34.290
#
# <sol> 1.1,3.3,3.9,4.7,1.1,3.0,4.2,2.1,6.0,3.1,5.0,3.4,7.0,3.6,7.0 <\sol>
# score: 0.630
#
# <sol> 2.5,2.4,1.2,4.6,1.6,3.0,1.8,4.8,7.0,2.7,9.0,1.3,5.0,3.4,5.0 <\sol>
# score: -15.010
#
# <sol> 1.8,3.5,1.1,2.9,3.7,1.6,1.7,4.4,5.0,2.3,7.0,2.6,5.0,4.5,9.0 <\sol>
# score: -25.880
#
# <sol> 1.5,1.3,3.8,2.7,3.5,4.3,1.9,4.5,9.0,2.3,7.0,4.0,4.0,2.4,9.0 <\sol>
# score: 23.880
#
# <sol> 4.9,3.0,2.5,2.7,3.3,3.5,3.4,5.0,4.0,3.8,4.0,2.4,4.0,1.0,7.0 <\sol>
# score: -33.060
#
# <sol> 1.7,3.3,2.0,2.6,1.7,4.4,4.4,4.2,7.0,1.4,4.0,4.8,7.0,5.0,5.0 <\sol>
# score: 17.800
#
# <sol> 4.2,3.2,3.3,4.6,4.4,4.9,3.1,3.6,8.0,4.4,9.0,1.0,6.0,4.4,4.0 <\sol>
# score: 29.720
#
# <sol> 1.4,3.5,2.3,4.8,3.6,1.8,2.4,2.4,4.0,3.5,7.0,2.2,8.0,4.1,7.0 <\sol>
# score: 4.850
#
# <sol> 3.9,4.6,3.2,4.8,2.4,3.8,4.5,2.2,7.0,4.1,5.0,1.6,5.0,3.1,8.0 <\sol>
# score: 4.940
#
# <sol> 1.5,3.7,3.7,2.9,3.9,2.0,3.7,3.4,4.0,4.8,6.0,4.2,9.0,1.0,4.0 <\sol>
# score: 21.990
#
# <sol> 2.2,5.0,1.2,4.8,1.5,1.7,3.6,1.8,6.0,4.6,9.0,4.2,4.0,3.3,7.0 <\sol>
# score: -94.050
#
# <sol> 2.1,4.8,1.1,1.2,4.6,2.6,1.1,1.1,4.0,3.7,4.0,3.2,6.0,4.6,9.0 <\sol>
# score: -60.960
#
# <sol> 1.1,3.5,4.1,1.5,4.1,1.3,2.0,2.6,7.0,4.7,5.0,3.3,9.0,1.4,9.0 <\sol>
# score: -13.290
#
# <sol> 2.0,2.5,4.2,1.8,1.5,2.5,3.8,1.2,5.0,2.9,6.0,4.5,6.0,2.8,7.0 <\sol>
# score: -33.880
#
# <sol> 4.1,1.6,5.0,4.2,4.9,4.8,2.7,4.9,4.0,1.0,4.0,2.0,5.0,3.7,9.0 <\sol>
# score: 25.670
#
#
# Generate exactly 5 new solutions that:
# - Are distinct from all previous solutions.
# - Have higher scores than the highest provided.
# - Respect the relationships based on logical reasoning.
#
# Each solution should start with <sol> and end with <\sol> with a comma between parameters.
# Make sure the length of solutions match examples given. Don't guess for the scores as they will be calculated by an objective function.
#
# Response:
# ```
# <sol> 4.5,2.8,3.0,4.7,4.6,4.8,3.2,3.7,8.0,4.5,9.0,4.5,6.0,4.5,5.0 </sol>
# <sol> 4.7,2.9,3.1,4.8,4.7,4.9,3.3,3.8,9.0,4.6,8.0,4.6,5.0,4.6,6.0 </sol>
# <sol> 4.3,2.7,2.9,4.5,4.4,4.6,3.0,3.5,7.0,4.3,8.0,4.3,5.0,4.3,4.0 </sol>
# <sol> 4.9,3.0,3.2,5.0,4.8,5.0,3.4,3.9,10.0,4.7,9.0,4.7,7.0,4.7,8.0 </sol>
# <sol> 4.0,2.6,2.8,4.1,4.0,4.2,2.9,3.3,6.0,4.1,7.0,4.1,4.0,4.1,3.0 </sol>
# ```
# ======================================================================================================================================================

# %%
from llmize.callbacks import EarlyStopping, AdaptTempOnPlateau, OptimalScoreStopping

# Define the early stopping callback
earlystop_callback = EarlyStopping(monitor='best_score', min_delta=0.1, patience=50, verbose=1)

# Define the optimal score stopping callback
optimal_score_callback = OptimalScoreStopping(optimal_score=100.0, tolerance=0.1)

# Define the temperature adaptation callback
adapt_temp_callback = AdaptTempOnPlateau(monitor='best_score', init_temperature=1.0, min_delta=0.1, patience=20, factor=1.1, max_temperature=1.9, verbose=1)

callbacks = [earlystop_callback, optimal_score_callback, adapt_temp_callback]

# %%
results = opro.maximize(init_samples=solutions, init_scores=scores, num_steps=250, batch_size=batch_size, callbacks=callbacks)
# Out:
# Running OPRO optimization with 250 steps and batch size 16...
# Step 0 - Best Initial Score: 29.720, Average Initial Score: -11.309
